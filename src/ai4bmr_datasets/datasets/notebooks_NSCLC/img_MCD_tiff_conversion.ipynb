# %%
import pandas as pd

# %%
df = pd.read_csv('/work/FAC/FBM/DBC/mrapsoma/prometex/data/NSCLC/01_raw/raw/panel.csv')
df.to_csv('/work/FAC/FBM/DBC/mrapsoma/prometex/data/NSCLC/01_raw/raw/raw_panel.csv', index=False)

df.rename(columns={"Metal Tag": "channel", "Target": "name"}, inplace=True)

df.to_csv('/work/FAC/FBM/DBC/mrapsoma/prometex/data/NSCLC/01_raw/raw/panel.csv', index=False)

# %%
df = pd.read_csv('/work/FAC/FBM/DBC/mrapsoma/prometex/data/NSCLC/01_raw/raw/panel.csv')

# drop raws not containint target protein
df = df.dropna(subset=["name"])

df.to_csv('/work/FAC/FBM/DBC/mrapsoma/prometex/data/NSCLC/01_raw/raw/panel.csv', index=False)

# %%
pd.read_csv('/work/FAC/FBM/DBC/mrapsoma/prometex/data/NSCLC/01_raw/raw/panel.csv')
# Out:
#     channel  name  keep  ilastik  deepcell  cellpose  Tube Number  \
# 0      As75     1     0      NaN       NaN       NaN          NaN
# 1      Se76     2     0      NaN       NaN       NaN          NaN
# 2      Se77     3     0      NaN       NaN       NaN          NaN
# 3      Se78     4     0      NaN       NaN       NaN          NaN
# 4    ArAr80     5     0      NaN       NaN       NaN          NaN
# ..      ...   ...   ...      ...       ...       ...          ...
# 127   Tl205    86     0      NaN       NaN       NaN          NaN
# 128   Pb207    87     0      NaN       NaN       NaN          NaN
# 129   Pb208    88     0      NaN       NaN       NaN          NaN
# 130   Bi209  CD15     1      NaN       NaN       NaN       2131.0
# 131  Hf1878    89     0      NaN       NaN       NaN          NaN
#
#     Antibody Clone  Stock Concentration Final Concentration / Dilution  \
# 0              NaN                  NaN                            NaN
# ...

# %%
df[df.duplicated(subset=['channel'], keep=False)]
# Out:
#     Tube Number channel                name         Antibody Clone  \
# 4        2030.0   Dy164              CD45RA                  HI100
# 5        2302.0   Dy164              CD45RO                  UCHL1
# 21       1879.0   Lu175     pan Cytokeratin                    AE1
# 22       2277.0   Lu175  Keratin Epithelial                    AE3
# 33       1702.0   Sm147          Collagen I  Polyclonal_Collagen I
# 34       1703.0   Sm147         Fibronectin         10/Fibronectin
# 42       2251.0   Yb172                 vWF               poly vwf
# 43       2280.0   Yb172                CD31                EPR3094
#
#     Stock Concentration Final Concentration / Dilution  uL to add  800 ul  \
# 4                 500.0                        2 ug/mL        0.4     3.2
# 5                 500.0                        2 ug/mL        0.4     3.2
# 21                500.0                        2 ug/mL        0.4     3.2
# ...

# %%
pd.read_csv('/work/FAC/FBM/DBC/mrapsoma/prometex/data/NSCLC/01_raw/raw/panel.csv')['channel'].values
# Out:
# array(['As75', 'Se76', 'Se77', 'Se78', 'ArAr80', 'Br81', 'Kr82', 'Kr83',
#        'Sr84', 'Rb85', 'Sr86', 'Sr87', 'Sr88', 'Y89', 'Zr90', 'Zr91',
#        'Zr92', 'Nb93', 'Mo94', 'Mo95', 'Mo96', 'Mo97', 'Mo98', 'Ru99',
#        'Ru100', 'Ru101', 'Ru102', 'Rh103', 'Pd104', 'Pd105', 'Pd106',
#        'Ag107', 'Cd108', 'Ag109', 'Cd110', 'Cd111', 'Cd112', 'In113',
#        'Cd114', 'In115', 'Sn116', 'Sn118', 'Sn119', 'Sn120', 'Sb121',
#        'Te122', 'Te123', 'Te124', 'Te125', 'Te126', 'I127', 'Xe128',
#        'Xe129', 'Xe130', 'Xe131', 'Xe132', 'Cs133', 'Ba134', 'Ba135',
#        'Ba136', 'Ba137', 'Ba138', 'La139', 'Ce140', 'Pr141', 'Nd142',
#        'Nd143', 'Nd144', 'Nd145', 'Nd146', 'Sm147', 'Nd148', 'Sm149',
#        'Nd150', 'Eu151', 'Sm152', 'Eu153', 'Sm154', 'Gd155', 'Gd156',
#        'Gd157', 'Gd158', 'Tb159', 'Gd160', 'Dy161', 'Dy162', 'Dy163',
#        'Dy164', 'Ho165', 'Er166', 'Er167', 'Er168', 'Tm169', 'Er170',
# ...

# %%
from imageio import imread

# %%
imread('/work/FAC/FBM/DBC/mrapsoma/prometex/data/NSCLC/01_raw/raw/img/2020117_LC_NSCLC_TMA_86_B_002.tiff').shape
# Out:
# /tmp/ipykernel_1513595/524506004.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   imread('/work/FAC/FBM/DBC/mrapsoma/prometex/data/NSCLC/01_raw/raw/img/2020117_LC_NSCLC_TMA_86_B_002.tiff').shape
# (43, 556, 531)

# %%
pd.read_csv('/work/FAC/FBM/DBC/mrapsoma/prometex/data/NSCLC/01_raw/raw/images_old.csv')
# Out:
#                                              image  width_px  height_px  \
# 0               2020117_LC_NSCLC_TMA_86_B_002.tiff       531        556
# 1               2020117_LC_NSCLC_TMA_86_B_003.tiff       640        729
# 2               2020117_LC_NSCLC_TMA_86_B_004.tiff       676        707
# 3               2020117_LC_NSCLC_TMA_86_B_005.tiff       652        628
# 4               2020117_LC_NSCLC_TMA_86_B_006.tiff       658        673
# ..                                             ...       ...        ...
# 134  20210205_CompSlide_NSCLC_TMA_LC_Yb171_18.tiff       200        100
# 135  20210205_CompSlide_NSCLC_TMA_LC_Yb172_41.tiff       200        100
# 136   20210205_CompSlide_NSCLC_TMA_LC_Yb173_7.tiff       200        100
# 137   20210205_CompSlide_NSCLC_TMA_LC_Yb174_9.tiff       200        100
# 138  20210205_CompSlide_NSCLC_TMA_LC_Yb176_36.tiff       200        100
#
#      num_channels                                   source_file  \
# ...
